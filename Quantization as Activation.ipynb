# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from torch import nn
import torch.nn.functional as F

import torchvision

import torchsummary

from models.vgg import VGG
from utils.run import run_one_epoch

# %%
transform_valid = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.RandomCrop(32, padding=4),
    torchvision.transforms.RandomHorizontalFlip(),
    transform_valid,
])



trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True, num_workers=16, pin_memory=True)

validset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_valid)
validloader = torch.utils.data.DataLoader(validset, batch_size=512, shuffle=False, num_workers=16, pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
model = VGG('VGG16')
torchsummary.summary(model.cpu(), (3, 32, 32), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#         MaxPool2d-14            [-1, 128, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         295,168
#       BatchNorm2d-16            [-1, 256, 8, 8]             512
#              ReLU-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-19            [-1, 256, 8, 8]             512
#              ReLU-20            [-1, 256, 8, 8]               0
#            Conv2d-21            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-22            [-1, 256, 8, 8]             512
#              ReLU-23            [-1, 256, 8, 8]               0
#         MaxPool2d-24            [-1, 256, 4, 4]               0
#            Conv2d-25            [-1, 512, 4, 4]       1,180,160
#       BatchNorm2d-26            [-1, 512, 4, 4]           1,024
#              ReLU-27            [-1, 512, 4, 4]               0
#            Conv2d-28            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-29            [-1, 512, 4, 4]           1,024
#              ReLU-30            [-1, 512, 4, 4]               0
#            Conv2d-31            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-32            [-1, 512, 4, 4]           1,024
#              ReLU-33            [-1, 512, 4, 4]               0
#         MaxPool2d-34            [-1, 512, 2, 2]               0
#            Conv2d-35            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-36            [-1, 512, 2, 2]           1,024
#              ReLU-37            [-1, 512, 2, 2]               0
#            Conv2d-38            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-39            [-1, 512, 2, 2]           1,024
#              ReLU-40            [-1, 512, 2, 2]               0
#            Conv2d-41            [-1, 512, 2, 2]       2,359,808
#       BatchNorm2d-42            [-1, 512, 2, 2]           1,024
#              ReLU-43            [-1, 512, 2, 2]               0
#         MaxPool2d-44            [-1, 512, 1, 1]               0
#         AvgPool2d-45            [-1, 512, 1, 1]               0
#            Linear-46                   [-1, 10]           5,130
# ================================================================
# Total params: 14,728,266
# Trainable params: 14,728,266
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.57
# Params size (MB): 56.18
# Estimated Total Size (MB): 62.77
# ----------------------------------------------------------------

# %%
# Train baseline model

# optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9, weight_decay=5e-4)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

num_epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = model.to(device)

history = {
    'epoch': [],
    'train': {'loss': [], 'accuracy': []},
    'valid': {'loss': [], 'accuracy': []},
}

for epoch in range(num_epochs):
    print(f'{epoch+1} / {num_epochs}')
    train_loss, train_acc = run_one_epoch(model, trainloader, criterion=criterion, optimizer=optimizer, device=device)
    print(f'\tTrain | Loss: {train_loss:.2e} Accuracy: {train_acc:.2%}')
    valid_loss, valid_acc = run_one_epoch(model, validloader, criterion=criterion, device=device)
    print(f'\tTrain | Loss: {valid_loss:.2e} Accuracy: {valid_acc:.2%}')
    scheduler.step()

    history['epoch'].append(epoch)
    history['train']['loss'].append(train_loss)
    history['train']['accuracy'].append(train_acc)
    history['valid']['loss'].append(valid_loss)
    history['valid']['accuracy'].append(valid_acc)
# Out:
# 1 / 50
# 	Train | Loss: 2.90e+00 Accuracy: 10.91%
# 	Train | Loss: 2.32e+00 Accuracy: 10.38%
# 2 / 50
# 	Train | Loss: 2.31e+00 Accuracy: 11.34%
# 	Train | Loss: 2.29e+00 Accuracy: 10.58%
# 3 / 50
# 	Train | Loss: 2.26e+00 Accuracy: 14.52%
# 	Train | Loss: 2.15e+00 Accuracy: 19.22%
# 4 / 50
# 	Train | Loss: 2.08e+00 Accuracy: 20.55%
# 	Train | Loss: 1.99e+00 Accuracy: 22.12%
# 5 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 23.45%
# 	Train | Loss: 2.19e+00 Accuracy: 17.23%
# 6 / 50
# 	Train | Loss: 1.87e+00 Accuracy: 25.68%
# 	Train | Loss: 1.88e+00 Accuracy: 26.17%
# 7 / 50
# 	Train | Loss: 1.81e+00 Accuracy: 28.17%
# 	Train | Loss: 1.80e+00 Accuracy: 27.95%
# 8 / 50
# 	Train | Loss: 1.75e+00 Accuracy: 30.98%
# 	Train | Loss: 1.94e+00 Accuracy: 28.54%
# 9 / 50
# 	Train | Loss: 1.66e+00 Accuracy: 34.27%
# 	Train | Loss: 1.68e+00 Accuracy: 33.25%
# 10 / 50
# 	Train | Loss: 1.56e+00 Accuracy: 39.19%
# 	Train | Loss: 1.63e+00 Accuracy: 36.71%
# 11 / 50
# 	Train | Loss: 1.46e+00 Accuracy: 43.96%
# 	Train | Loss: 1.53e+00 Accuracy: 42.65%
# 12 / 50
# 	Train | Loss: 1.31e+00 Accuracy: 50.78%
# 	Train | Loss: 1.40e+00 Accuracy: 48.27%
# 13 / 50
# 	Train | Loss: 1.15e+00 Accuracy: 57.82%
# 	Train | Loss: 1.49e+00 Accuracy: 49.17%
# 14 / 50
# 	Train | Loss: 1.00e+00 Accuracy: 64.26%
# 	Train | Loss: 1.09e+00 Accuracy: 60.89%
# 15 / 50
# 	Train | Loss: 8.81e-01 Accuracy: 68.93%
# 	Train | Loss: 1.02e+00 Accuracy: 64.74%
# 16 / 50
# 	Train | Loss: 7.92e-01 Accuracy: 72.15%
# 	Train | Loss: 8.61e-01 Accuracy: 70.26%
# 17 / 50
# 	Train | Loss: 7.22e-01 Accuracy: 74.93%
# 	Train | Loss: 7.95e-01 Accuracy: 71.59%
# 18 / 50
# 	Train | Loss: 6.62e-01 Accuracy: 77.19%
# 	Train | Loss: 7.79e-01 Accuracy: 73.24%
# 19 / 50
# 	Train | Loss: 6.08e-01 Accuracy: 79.23%
# 	Train | Loss: 7.15e-01 Accuracy: 75.55%
# 20 / 50
# 	Train | Loss: 5.61e-01 Accuracy: 80.78%
# 	Train | Loss: 8.40e-01 Accuracy: 71.02%
# 21 / 50
# 	Train | Loss: 5.33e-01 Accuracy: 81.94%
# 	Train | Loss: 8.13e-01 Accuracy: 73.90%
# 22 / 50
# 	Train | Loss: 4.89e-01 Accuracy: 83.62%
# 	Train | Loss: 8.96e-01 Accuracy: 71.99%
# 23 / 50
# 	Train | Loss: 4.65e-01 Accuracy: 84.34%
# 	Train | Loss: 5.71e-01 Accuracy: 81.31%
# 24 / 50
# 	Train | Loss: 4.37e-01 Accuracy: 85.30%
# 	Train | Loss: 5.64e-01 Accuracy: 81.01%
# 25 / 50
# 	Train | Loss: 4.14e-01 Accuracy: 86.03%
# 	Train | Loss: 6.08e-01 Accuracy: 80.21%
# 26 / 50
# 	Train | Loss: 3.96e-01 Accuracy: 86.70%
# 	Train | Loss: 6.39e-01 Accuracy: 80.71%
# 27 / 50
# 	Train | Loss: 3.82e-01 Accuracy: 87.27%
# 	Train | Loss: 5.87e-01 Accuracy: 80.14%
# 28 / 50
# 	Train | Loss: 3.68e-01 Accuracy: 87.56%
# 	Train | Loss: 5.98e-01 Accuracy: 80.92%
# 29 / 50
# 	Train | Loss: 3.56e-01 Accuracy: 87.92%
# 	Train | Loss: 5.55e-01 Accuracy: 82.26%
# 30 / 50
# 	Train | Loss: 3.39e-01 Accuracy: 88.55%
# 	Train | Loss: 5.32e-01 Accuracy: 82.54%
# 31 / 50
# 	Train | Loss: 3.23e-01 Accuracy: 89.11%
# 	Train | Loss: 6.90e-01 Accuracy: 78.29%
# 32 / 50
# 	Train | Loss: 3.16e-01 Accuracy: 89.25%
# 	Train | Loss: 5.73e-01 Accuracy: 81.01%
# 33 / 50
# 	Train | Loss: 3.10e-01 Accuracy: 89.50%
# 	Train | Loss: 6.09e-01 Accuracy: 80.55%
# 34 / 50
# 	Train | Loss: 2.95e-01 Accuracy: 90.01%
# 	Train | Loss: 5.43e-01 Accuracy: 82.67%
# 35 / 50
# 	Train | Loss: 2.89e-01 Accuracy: 90.20%
# 	Train | Loss: 6.65e-01 Accuracy: 81.05%
# 36 / 50
# 	Train | Loss: 2.86e-01 Accuracy: 90.07%
# 	Train | Loss: 5.12e-01 Accuracy: 83.72%
# 37 / 50
# 	Train | Loss: 2.74e-01 Accuracy: 90.73%
# 	Train | Loss: 5.06e-01 Accuracy: 83.71%
# 38 / 50
# 	Train | Loss: 2.66e-01 Accuracy: 90.90%
# 	Train | Loss: 4.61e-01 Accuracy: 85.26%
# 39 / 50
# 	Train | Loss: 2.55e-01 Accuracy: 91.41%
# 	Train | Loss: 4.60e-01 Accuracy: 85.07%
# 40 / 50
# 	Train | Loss: 2.57e-01 Accuracy: 91.22%
# 	Train | Loss: 5.73e-01 Accuracy: 82.49%
# 41 / 50
# 	Train | Loss: 2.45e-01 Accuracy: 91.63%
# 	Train | Loss: 4.48e-01 Accuracy: 85.92%
# 42 / 50
# 	Train | Loss: 2.41e-01 Accuracy: 91.79%
# 	Train | Loss: 4.14e-01 Accuracy: 86.27%
# 43 / 50
# 	Train | Loss: 2.33e-01 Accuracy: 92.10%
# 	Train | Loss: 8.08e-01 Accuracy: 76.67%
# 44 / 50
# 	Train | Loss: 2.25e-01 Accuracy: 92.36%
# 	Train | Loss: 4.45e-01 Accuracy: 85.67%
# 45 / 50
# 	Train | Loss: 2.15e-01 Accuracy: 92.66%
# 	Train | Loss: 7.18e-01 Accuracy: 79.22%
# 46 / 50
# 	Train | Loss: 2.15e-01 Accuracy: 92.68%
# 	Train | Loss: 5.90e-01 Accuracy: 82.15%
# 47 / 50
# 	Train | Loss: 2.08e-01 Accuracy: 92.91%
# 	Train | Loss: 4.71e-01 Accuracy: 85.40%
# 48 / 50
# 	Train | Loss: 2.11e-01 Accuracy: 92.72%
# 	Train | Loss: 5.20e-01 Accuracy: 83.75%
# 49 / 50
# 	Train | Loss: 2.05e-01 Accuracy: 92.89%
# 	Train | Loss: 4.60e-01 Accuracy: 86.09%
# 50 / 50
# 	Train | Loss: 1.93e-01 Accuracy: 93.39%
# 	Train | Loss: 4.80e-01 Accuracy: 85.27%

# %%
# Train model with no activation
model_no_act = VGG('VGG16', act_cls=nn.Identity)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)
optimizer = torch.optim.SGD(model_no_act.parameters(), lr=1e-1, momentum=0.9, weight_decay=5e-4)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

num_epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model_no_act = model_no_act.to(device)

history_no_act = {
    'epoch': [],
    'train': {'loss': [], 'accuracy': []},
    'valid': {'loss': [], 'accuracy': []},
}

for epoch in range(num_epochs):
    print(f'{epoch+1} / {num_epochs}')
    train_loss, train_acc = run_one_epoch(model_no_act, trainloader, criterion=criterion, optimizer=optimizer, device=device)
    print(f'\tTrain | Loss: {train_loss:.2e} Accuracy: {train_acc:.2%}')
    valid_loss, valid_acc = run_one_epoch(model_no_act, validloader, criterion=criterion, device=device)
    print(f'\tTrain | Loss: {valid_loss:.2e} Accuracy: {valid_acc:.2%}')
    scheduler.step()

    history_no_act['epoch'].append(epoch)
    history_no_act['train']['loss'].append(train_loss)
    history_no_act['train']['accuracy'].append(train_acc)
    history_no_act['valid']['loss'].append(valid_loss)
    history_no_act['valid']['accuracy'].append(valid_acc)
# Out:
# 1 / 50
# 	Train | Loss: 4.07e+00 Accuracy: 15.46%
# 	Train | Loss: 2.08e+00 Accuracy: 22.61%
# 2 / 50
# 	Train | Loss: 2.03e+00 Accuracy: 23.07%
# 	Train | Loss: 1.98e+00 Accuracy: 22.55%
# 3 / 50
# 	Train | Loss: 1.86e+00 Accuracy: 28.26%
# 	Train | Loss: 1.85e+00 Accuracy: 31.15%
# 4 / 50
# 	Train | Loss: 1.74e+00 Accuracy: 34.00%
# 	Train | Loss: 1.77e+00 Accuracy: 34.08%
# 5 / 50
# 	Train | Loss: 1.64e+00 Accuracy: 37.73%
# 	Train | Loss: 1.79e+00 Accuracy: 33.86%
# 6 / 50
# 	Train | Loss: 1.58e+00 Accuracy: 40.47%
# 	Train | Loss: 1.87e+00 Accuracy: 31.94%
# 7 / 50
# 	Train | Loss: 1.50e+00 Accuracy: 43.33%
# 	Train | Loss: 1.55e+00 Accuracy: 42.05%
# 8 / 50
# 	Train | Loss: 1.46e+00 Accuracy: 45.29%
# 	Train | Loss: 1.63e+00 Accuracy: 40.40%
# 9 / 50
# 	Train | Loss: 1.40e+00 Accuracy: 48.31%
# 	Train | Loss: 1.48e+00 Accuracy: 46.85%
# 10 / 50
# 	Train | Loss: 1.35e+00 Accuracy: 50.55%
# 	Train | Loss: 1.47e+00 Accuracy: 45.77%
# 11 / 50
# 	Train | Loss: 1.29e+00 Accuracy: 52.96%
# 	Train | Loss: 1.29e+00 Accuracy: 53.87%
# 12 / 50
# 	Train | Loss: 1.21e+00 Accuracy: 56.07%
# 	Train | Loss: 1.24e+00 Accuracy: 55.16%
# 13 / 50
# 	Train | Loss: 1.16e+00 Accuracy: 58.26%
# 	Train | Loss: 1.20e+00 Accuracy: 56.44%
# 14 / 50
# 	Train | Loss: 1.11e+00 Accuracy: 60.19%
# 	Train | Loss: 1.26e+00 Accuracy: 56.55%
# 15 / 50
# 	Train | Loss: 1.05e+00 Accuracy: 62.51%
# 	Train | Loss: 1.12e+00 Accuracy: 59.97%
# 16 / 50
# 	Train | Loss: 1.02e+00 Accuracy: 63.72%
# 	Train | Loss: 1.06e+00 Accuracy: 62.13%
# 17 / 50
# 	Train | Loss: 9.88e-01 Accuracy: 64.87%
# 	Train | Loss: 9.79e-01 Accuracy: 65.16%
# 18 / 50
# 	Train | Loss: 9.48e-01 Accuracy: 66.04%
# 	Train | Loss: 1.11e+00 Accuracy: 61.75%
# 19 / 50
# 	Train | Loss: 9.26e-01 Accuracy: 67.12%
# 	Train | Loss: 1.09e+00 Accuracy: 62.41%
# 20 / 50
# 	Train | Loss: 8.99e-01 Accuracy: 68.17%
# 	Train | Loss: 9.95e-01 Accuracy: 64.43%
# 21 / 50
# 	Train | Loss: 8.75e-01 Accuracy: 69.00%
# 	Train | Loss: 9.76e-01 Accuracy: 66.05%
# 22 / 50
# 	Train | Loss: 8.49e-01 Accuracy: 69.78%
# 	Train | Loss: 8.69e-01 Accuracy: 69.61%
# 23 / 50
# 	Train | Loss: 8.29e-01 Accuracy: 70.89%
# 	Train | Loss: 9.46e-01 Accuracy: 66.46%
# 24 / 50
# 	Train | Loss: 8.02e-01 Accuracy: 71.90%
# 	Train | Loss: 1.02e+00 Accuracy: 64.84%
# 25 / 50
# 	Train | Loss: 7.85e-01 Accuracy: 72.39%
# 	Train | Loss: 8.39e-01 Accuracy: 71.39%
# 26 / 50
# 	Train | Loss: 7.67e-01 Accuracy: 72.92%
# 	Train | Loss: 7.91e-01 Accuracy: 73.10%
# 27 / 50
# 	Train | Loss: 7.49e-01 Accuracy: 73.92%
# 	Train | Loss: 7.72e-01 Accuracy: 73.42%
# 28 / 50
# 	Train | Loss: 7.21e-01 Accuracy: 74.98%
# 	Train | Loss: 7.61e-01 Accuracy: 73.76%
# 29 / 50
# 	Train | Loss: 7.05e-01 Accuracy: 75.39%
# 	Train | Loss: 7.51e-01 Accuracy: 73.95%
# 30 / 50
# 	Train | Loss: 6.90e-01 Accuracy: 75.84%
# 	Train | Loss: 7.16e-01 Accuracy: 75.25%
# 31 / 50
# 	Train | Loss: 6.79e-01 Accuracy: 76.41%
# 	Train | Loss: 6.95e-01 Accuracy: 76.10%
# 32 / 50
# 	Train | Loss: 6.66e-01 Accuracy: 76.87%
# 	Train | Loss: 7.81e-01 Accuracy: 73.56%
# 33 / 50
# 	Train | Loss: 6.50e-01 Accuracy: 77.55%
# 	Train | Loss: 8.10e-01 Accuracy: 73.27%
# 34 / 50
# 	Train | Loss: 6.40e-01 Accuracy: 77.87%
# 	Train | Loss: 7.13e-01 Accuracy: 75.73%
# 35 / 50
# 	Train | Loss: 6.29e-01 Accuracy: 78.20%
# 	Train | Loss: 7.76e-01 Accuracy: 74.65%
# 36 / 50
# 	Train | Loss: 6.12e-01 Accuracy: 78.81%
# 	Train | Loss: 6.69e-01 Accuracy: 77.32%
# 37 / 50
# 	Train | Loss: 6.06e-01 Accuracy: 78.95%
# 	Train | Loss: 6.23e-01 Accuracy: 78.59%
# 38 / 50
# 	Train | Loss: 5.91e-01 Accuracy: 79.58%
# 	Train | Loss: 7.04e-01 Accuracy: 75.69%
# 39 / 50
# 	Train | Loss: 5.89e-01 Accuracy: 79.42%
# 	Train | Loss: 7.24e-01 Accuracy: 74.66%
# 40 / 50
# 	Train | Loss: 5.81e-01 Accuracy: 79.71%
# 	Train | Loss: 6.97e-01 Accuracy: 76.54%
# 41 / 50
# 	Train | Loss: 5.76e-01 Accuracy: 79.91%
# 	Train | Loss: 6.59e-01 Accuracy: 78.04%
# 42 / 50
# 	Train | Loss: 5.64e-01 Accuracy: 80.60%
# 	Train | Loss: 7.26e-01 Accuracy: 75.17%
# 43 / 50
# 	Train | Loss: 5.61e-01 Accuracy: 80.63%
# 	Train | Loss: 6.11e-01 Accuracy: 79.78%
# 44 / 50
# 	Train | Loss: 5.42e-01 Accuracy: 81.10%
# 	Train | Loss: 6.40e-01 Accuracy: 78.26%
# 45 / 50
# 	Train | Loss: 5.47e-01 Accuracy: 81.13%
# 	Train | Loss: 6.29e-01 Accuracy: 78.97%
# 46 / 50
# 	Train | Loss: 5.40e-01 Accuracy: 81.14%
# 	Train | Loss: 5.86e-01 Accuracy: 79.89%
# 47 / 50
# 	Train | Loss: 5.40e-01 Accuracy: 81.31%
# 	Train | Loss: 6.27e-01 Accuracy: 78.67%
# 48 / 50
# 	Train | Loss: 5.26e-01 Accuracy: 81.73%
# 	Train | Loss: 5.80e-01 Accuracy: 80.42%
# 49 / 50
# 	Train | Loss: 5.13e-01 Accuracy: 82.25%
# 	Train | Loss: 6.37e-01 Accuracy: 78.16%
# 50 / 50
# 	Train | Loss: 5.22e-01 Accuracy: 81.96%
# 	Train | Loss: 5.98e-01 Accuracy: 79.87%

# %%
# Train model with no pooling, but with ReLU activation

model_no_pool = VGG('VGG16', pool='strided')

# optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)
optimizer = torch.optim.SGD(model_no_pool.parameters(), lr=1e-1, momentum=0.9, weight_decay=5e-4)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

num_epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model_no_pool = model_no_pool.to(device)

history_no_pool = {
    'epoch': [],
    'train': {'loss': [], 'accuracy': []},
    'valid': {'loss': [], 'accuracy': []},
}

for epoch in range(num_epochs):
    print(f'{epoch+1} / {num_epochs}')
    train_loss, train_acc = run_one_epoch(model_no_pool, trainloader, criterion=criterion, optimizer=optimizer, device=device)
    print(f'\tTrain | Loss: {train_loss:.2e} Accuracy: {train_acc:.2%}')
    valid_loss, valid_acc = run_one_epoch(model_no_pool, validloader, criterion=criterion, device=device)
    print(f'\tTrain | Loss: {valid_loss:.2e} Accuracy: {valid_acc:.2%}')
    scheduler.step()

    history_no_pool['epoch'].append(epoch)
    history_no_pool['train']['loss'].append(train_loss)
    history_no_pool['train']['accuracy'].append(train_acc)
    history_no_pool['valid']['loss'].append(valid_loss)
    history_no_pool['valid']['accuracy'].append(valid_acc)
# Out:
# 1 / 50
# 	Train | Loss: 1.86e+00 Accuracy: 31.64%
# 	Train | Loss: 2.08e+00 Accuracy: 40.61%
# 2 / 50
# 	Train | Loss: 1.55e+00 Accuracy: 43.00%
# 	Train | Loss: 1.47e+00 Accuracy: 45.65%
# 3 / 50
# 	Train | Loss: 1.41e+00 Accuracy: 48.62%
# 	Train | Loss: 1.57e+00 Accuracy: 46.52%
# 4 / 50
# 	Train | Loss: 1.31e+00 Accuracy: 52.44%
# 	Train | Loss: 1.22e+00 Accuracy: 56.11%
# 5 / 50
# 	Train | Loss: 1.19e+00 Accuracy: 57.23%
# 	Train | Loss: 1.11e+00 Accuracy: 60.31%
# 6 / 50
# 	Train | Loss: 1.11e+00 Accuracy: 60.29%
# 	Train | Loss: 1.04e+00 Accuracy: 63.25%
# 7 / 50
# 	Train | Loss: 1.05e+00 Accuracy: 62.39%
# 	Train | Loss: 1.01e+00 Accuracy: 64.11%
# 8 / 50
# 	Train | Loss: 1.00e+00 Accuracy: 64.46%
# 	Train | Loss: 9.54e-01 Accuracy: 66.56%
# 9 / 50
# 	Train | Loss: 9.56e-01 Accuracy: 66.41%
# 	Train | Loss: 9.81e-01 Accuracy: 66.12%
# 10 / 50
# 	Train | Loss: 9.15e-01 Accuracy: 67.80%
# 	Train | Loss: 8.92e-01 Accuracy: 69.50%
# 11 / 50
# 	Train | Loss: 8.83e-01 Accuracy: 69.00%
# 	Train | Loss: 9.14e-01 Accuracy: 68.00%
# 12 / 50
# 	Train | Loss: 8.52e-01 Accuracy: 70.29%
# 	Train | Loss: 8.43e-01 Accuracy: 71.05%
# 13 / 50
# 	Train | Loss: 8.20e-01 Accuracy: 71.29%
# 	Train | Loss: 8.64e-01 Accuracy: 70.25%
# 14 / 50
# 	Train | Loss: 8.06e-01 Accuracy: 71.99%
# 	Train | Loss: 7.91e-01 Accuracy: 73.00%
# 15 / 50
# 	Train | Loss: 7.85e-01 Accuracy: 72.72%
# 	Train | Loss: 7.75e-01 Accuracy: 73.61%
# 16 / 50
# 	Train | Loss: 7.68e-01 Accuracy: 73.26%
# 	Train | Loss: 8.67e-01 Accuracy: 69.63%
# 17 / 50
# 	Train | Loss: 7.50e-01 Accuracy: 73.60%
# 	Train | Loss: 7.83e-01 Accuracy: 73.21%
# 18 / 50
# 	Train | Loss: 7.32e-01 Accuracy: 74.68%
# 	Train | Loss: 7.94e-01 Accuracy: 72.69%
# 19 / 50
# 	Train | Loss: 7.15e-01 Accuracy: 75.09%
# 	Train | Loss: 7.59e-01 Accuracy: 74.69%
# 20 / 50
# 	Train | Loss: 7.16e-01 Accuracy: 75.27%
# 	Train | Loss: 7.75e-01 Accuracy: 73.71%
# 21 / 50
# 	Train | Loss: 7.06e-01 Accuracy: 75.51%
# 	Train | Loss: 7.49e-01 Accuracy: 74.11%
# 22 / 50
# 	Train | Loss: 6.89e-01 Accuracy: 76.07%
# 	Train | Loss: 7.12e-01 Accuracy: 75.52%
# 23 / 50
# 	Train | Loss: 6.87e-01 Accuracy: 76.34%
# 	Train | Loss: 7.59e-01 Accuracy: 74.38%
# 24 / 50
# 	Train | Loss: 6.80e-01 Accuracy: 76.46%
# 	Train | Loss: 7.49e-01 Accuracy: 74.60%
# 25 / 50
# 	Train | Loss: 6.65e-01 Accuracy: 76.95%
# 	Train | Loss: 7.24e-01 Accuracy: 75.43%
# 26 / 50
# 	Train | Loss: 6.59e-01 Accuracy: 77.42%
# 	Train | Loss: 6.78e-01 Accuracy: 77.22%
# 27 / 50
# 	Train | Loss: 6.46e-01 Accuracy: 77.72%
# 	Train | Loss: 6.97e-01 Accuracy: 76.74%
# 28 / 50
# 	Train | Loss: 6.48e-01 Accuracy: 77.64%
# 	Train | Loss: 7.70e-01 Accuracy: 74.64%
# 29 / 50
# 	Train | Loss: 6.34e-01 Accuracy: 77.95%
# 	Train | Loss: 7.85e-01 Accuracy: 73.81%
# 30 / 50
# 	Train | Loss: 6.51e-01 Accuracy: 77.62%
# 	Train | Loss: 7.56e-01 Accuracy: 74.44%
# 31 / 50
# 	Train | Loss: 6.27e-01 Accuracy: 78.48%
# 	Train | Loss: 6.81e-01 Accuracy: 77.04%
# 32 / 50
# 	Train | Loss: 6.24e-01 Accuracy: 78.45%
# 	Train | Loss: 6.68e-01 Accuracy: 77.20%
# 33 / 50
# 	Train | Loss: 6.16e-01 Accuracy: 78.75%
# 	Train | Loss: 7.43e-01 Accuracy: 74.63%
# 34 / 50
# 	Train | Loss: 6.15e-01 Accuracy: 78.79%
# 	Train | Loss: 6.89e-01 Accuracy: 76.62%
# 35 / 50
# 	Train | Loss: 6.10e-01 Accuracy: 79.02%
# 	Train | Loss: 6.90e-01 Accuracy: 76.04%
# 36 / 50
# 	Train | Loss: 5.98e-01 Accuracy: 79.13%
# 	Train | Loss: 6.30e-01 Accuracy: 78.80%
# 37 / 50
# 	Train | Loss: 5.98e-01 Accuracy: 79.32%
# 	Train | Loss: 6.82e-01 Accuracy: 77.18%
# 38 / 50
# 	Train | Loss: 5.89e-01 Accuracy: 79.49%
# 	Train | Loss: 7.33e-01 Accuracy: 75.56%
# 39 / 50
# 	Train | Loss: 5.87e-01 Accuracy: 79.77%
# 	Train | Loss: 6.66e-01 Accuracy: 77.45%
# 40 / 50
# 	Train | Loss: 5.82e-01 Accuracy: 79.90%
# 	Train | Loss: 6.75e-01 Accuracy: 76.89%
# 41 / 50
# 	Train | Loss: 5.88e-01 Accuracy: 79.86%
# 	Train | Loss: 6.63e-01 Accuracy: 77.46%
# 42 / 50
# 	Train | Loss: 5.88e-01 Accuracy: 79.58%
# 	Train | Loss: 6.76e-01 Accuracy: 77.44%
# 43 / 50
# 	Train | Loss: 5.76e-01 Accuracy: 80.00%
# 	Train | Loss: 6.97e-01 Accuracy: 77.16%
# 44 / 50
# 	Train | Loss: 5.70e-01 Accuracy: 80.21%
# 	Train | Loss: 7.19e-01 Accuracy: 76.41%
# 45 / 50
# 	Train | Loss: 5.77e-01 Accuracy: 80.00%
# 	Train | Loss: 6.39e-01 Accuracy: 77.86%
# 46 / 50
# 	Train | Loss: 5.63e-01 Accuracy: 80.49%
# 	Train | Loss: 6.92e-01 Accuracy: 76.94%
# 47 / 50
# 	Train | Loss: 5.56e-01 Accuracy: 80.77%
# 	Train | Loss: 7.10e-01 Accuracy: 76.38%
# 48 / 50
# 	Train | Loss: 5.54e-01 Accuracy: 80.77%
# 	Train | Loss: 6.45e-01 Accuracy: 78.17%
# 49 / 50
# 	Train | Loss: 5.53e-01 Accuracy: 80.95%
# 	Train | Loss: 6.23e-01 Accuracy: 78.57%
# 50 / 50
# 	Train | Loss: 5.44e-01 Accuracy: 81.15%
# 	Train | Loss: 6.38e-01 Accuracy: 79.00%

# %%
# Train model with no pooling and no activation

model_no_act_no_pool = VGG('VGG16', pool='strided', act_cls=nn.Identity)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)
optimizer = torch.optim.SGD(model_no_act_no_pool.parameters(), lr=1e-1, momentum=0.9, weight_decay=5e-4)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

num_epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model_no_act_no_pool = model_no_act_no_pool.to(device)

history_no_act_no_pool = {
    'epoch': [],
    'train': {'loss': [], 'accuracy': []},
    'valid': {'loss': [], 'accuracy': []},
}

for epoch in range(num_epochs):
    print(f'{epoch+1} / {num_epochs}')
    train_loss, train_acc = run_one_epoch(model_no_act_no_pool, trainloader, criterion=criterion, optimizer=optimizer, device=device)
    print(f'\tTrain | Loss: {train_loss:.2e} Accuracy: {train_acc:.2%}')
    valid_loss, valid_acc = run_one_epoch(model_no_act_no_pool, validloader, criterion=criterion, device=device)
    print(f'\tTrain | Loss: {valid_loss:.2e} Accuracy: {valid_acc:.2%}')
    scheduler.step()

    history_no_act_no_pool['epoch'].append(epoch)
    history_no_act_no_pool['train']['loss'].append(train_loss)
    history_no_act_no_pool['train']['accuracy'].append(train_acc)
    history_no_act_no_pool['valid']['loss'].append(valid_loss)
    history_no_act_no_pool['valid']['accuracy'].append(valid_acc)
# Out:
# 1 / 50
# 	Train | Loss: 3.21e+00 Accuracy: 16.88%
# 	Train | Loss: 2.09e+00 Accuracy: 22.68%
# 2 / 50
# 	Train | Loss: 2.13e+00 Accuracy: 21.31%
# 	Train | Loss: 2.05e+00 Accuracy: 25.12%
# 3 / 50
# 	Train | Loss: 2.04e+00 Accuracy: 24.74%
# 	Train | Loss: 1.99e+00 Accuracy: 26.98%
# 4 / 50
# 	Train | Loss: 2.02e+00 Accuracy: 25.61%
# 	Train | Loss: 1.94e+00 Accuracy: 28.30%
# 5 / 50
# 	Train | Loss: 2.00e+00 Accuracy: 26.01%
# 	Train | Loss: 1.92e+00 Accuracy: 28.94%
# 6 / 50
# 	Train | Loss: 1.98e+00 Accuracy: 26.99%
# 	Train | Loss: 1.92e+00 Accuracy: 28.95%
# 7 / 50
# 	Train | Loss: 1.97e+00 Accuracy: 27.75%
# 	Train | Loss: 1.91e+00 Accuracy: 30.14%
# 8 / 50
# 	Train | Loss: 1.96e+00 Accuracy: 28.03%
# 	Train | Loss: 1.92e+00 Accuracy: 28.35%
# 9 / 50
# 	Train | Loss: 1.96e+00 Accuracy: 27.85%
# 	Train | Loss: 1.91e+00 Accuracy: 29.36%
# 10 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.87%
# 	Train | Loss: 1.89e+00 Accuracy: 32.63%
# 11 / 50
# 	Train | Loss: 1.93e+00 Accuracy: 30.26%
# 	Train | Loss: 1.85e+00 Accuracy: 33.57%
# 12 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.53%
# 	Train | Loss: 1.87e+00 Accuracy: 32.54%
# 13 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.57%
# 	Train | Loss: 1.87e+00 Accuracy: 31.71%
# 14 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.63%
# 	Train | Loss: 1.86e+00 Accuracy: 33.83%
# 15 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.60%
# 	Train | Loss: 1.86e+00 Accuracy: 34.10%
# 16 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.65%
# 	Train | Loss: 1.85e+00 Accuracy: 33.98%
# 17 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.98%
# 	Train | Loss: 1.86e+00 Accuracy: 32.51%
# 18 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.69%
# 	Train | Loss: 1.87e+00 Accuracy: 32.46%
# 19 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.99%
# 	Train | Loss: 1.86e+00 Accuracy: 33.24%
# 20 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.07%
# 	Train | Loss: 1.86e+00 Accuracy: 33.73%
# 21 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.86%
# 	Train | Loss: 1.86e+00 Accuracy: 33.71%
# 22 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.78%
# 	Train | Loss: 1.86e+00 Accuracy: 33.00%
# 23 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.73%
# 	Train | Loss: 1.87e+00 Accuracy: 32.35%
# 24 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.91%
# 	Train | Loss: 1.85e+00 Accuracy: 32.58%
# 25 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.06%
# 	Train | Loss: 1.85e+00 Accuracy: 34.33%
# 26 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.80%
# 	Train | Loss: 1.88e+00 Accuracy: 32.12%
# 27 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.00%
# 	Train | Loss: 1.87e+00 Accuracy: 32.23%
# 28 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.90%
# 	Train | Loss: 1.86e+00 Accuracy: 32.96%
# 29 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.85%
# 	Train | Loss: 1.86e+00 Accuracy: 33.28%
# 30 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.84%
# 	Train | Loss: 1.85e+00 Accuracy: 34.25%
# 31 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.20%
# 	Train | Loss: 1.88e+00 Accuracy: 32.45%
# 32 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.62%
# 	Train | Loss: 1.85e+00 Accuracy: 33.28%
# 33 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.08%
# 	Train | Loss: 1.84e+00 Accuracy: 33.49%
# 34 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.93%
# 	Train | Loss: 1.85e+00 Accuracy: 33.36%
# 35 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.85%
# 	Train | Loss: 1.86e+00 Accuracy: 33.15%
# 36 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.09%
# 	Train | Loss: 1.86e+00 Accuracy: 33.48%
# 37 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.78%
# 	Train | Loss: 1.85e+00 Accuracy: 33.85%
# 38 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.99%
# 	Train | Loss: 1.86e+00 Accuracy: 33.15%
# 39 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.50%
# 	Train | Loss: 1.84e+00 Accuracy: 33.86%
# 40 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.86%
# 	Train | Loss: 1.87e+00 Accuracy: 32.04%
# 41 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.79%
# 	Train | Loss: 1.85e+00 Accuracy: 33.10%
# 42 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.88%
# 	Train | Loss: 1.89e+00 Accuracy: 31.34%
# 43 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.83%
# 	Train | Loss: 1.86e+00 Accuracy: 33.09%
# 44 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.94%
# 	Train | Loss: 1.85e+00 Accuracy: 33.83%
# 45 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.88%
# 	Train | Loss: 1.87e+00 Accuracy: 32.18%
# 46 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.81%
# 	Train | Loss: 1.85e+00 Accuracy: 33.37%
# 47 / 50
# 	Train | Loss: 1.92e+00 Accuracy: 30.95%
# 	Train | Loss: 1.85e+00 Accuracy: 33.34%
# 48 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.21%
# 	Train | Loss: 1.85e+00 Accuracy: 32.20%
# 49 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 31.28%
# 	Train | Loss: 1.89e+00 Accuracy: 31.05%
# 50 / 50
# 	Train | Loss: 1.91e+00 Accuracy: 30.74%
# 	Train | Loss: 1.87e+00 Accuracy: 32.74%

# %%
# Train model with no pooling but with quantization function as activation
import math

# Because we will use a straight-through estimator (STE), we need to define the custom Autograd function

def calibrate(X, qmin, qmax):
    xmax = X.abs().max().item()  # Symmetric, signed
    scale = xmax * 2 / (qmax - qmin)
    # offset = -math.round(qmax - xmax / scale)
    return scale  # , offset

class _QuantDequantDynamic(torch.autograd.Function):
    @staticmethod
    def forward(ctx, X, qmin, qmax):
        scale = calibrate(X, qmin, qmax)
        qX = (X / scale).round().clip(qmin, qmax)
        # ctx.save_for_backward(scale)
        # Dequantize, as we are operating in emulation mode
        fX = qX * scale
        return fX

    @staticmethod
    def backward(ctx, dLdy):
        # STE
        return dLdy, None, None


class QdQ(nn.Module):
    # Symmetric, signed
    def __init__(self, num_bits=8, offset=False):
        super().__init__()
        assert not offset  # Ignoring for now
        self.qmin = -(1 << (num_bits - 1))
        self.qmax = -self.qmin
        self.offset = offset
        self._qdq_fn = _QuantDequantDynamic.apply

    def forward(self, X, *args, **kwargs):
        return self._qdq_fn(X, self.qmin, self.qmax)

model_quad_act_no_pool = VGG('VGG16', pool='strided', act_cls=QdQ)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)
optimizer = torch.optim.SGD(model_quad_act_no_pool.parameters(), lr=1e-1, momentum=0.9, weight_decay=5e-4)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

num_epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model_quad_act_no_pool = model_quad_act_no_pool.to(device)

history_quad_act_no_pool = {
    'epoch': [],
    'train': {'loss': [], 'accuracy': []},
    'valid': {'loss': [], 'accuracy': []},
}

for epoch in range(num_epochs):
    print(f'{epoch+1} / {num_epochs}')
    train_loss, train_acc = run_one_epoch(model_quad_act_no_pool, trainloader, criterion=criterion, optimizer=optimizer, device=device)
    print(f'\tTrain | Loss: {train_loss:.2e} Accuracy: {train_acc:.2%}')
    valid_loss, valid_acc = run_one_epoch(model_quad_act_no_pool, validloader, criterion=criterion, device=device)
    print(f'\tTrain | Loss: {valid_loss:.2e} Accuracy: {valid_acc:.2%}')
    scheduler.step()

    history_quad_act_no_pool['epoch'].append(epoch)
    history_quad_act_no_pool['train']['loss'].append(train_loss)
    history_quad_act_no_pool['train']['accuracy'].append(train_acc)
    history_quad_act_no_pool['valid']['loss'].append(valid_loss)
    history_quad_act_no_pool['valid']['accuracy'].append(valid_acc)
# Out:
# 1 / 50
# 	Train | Loss: 3.80e+00 Accuracy: 16.55%
# 	Train | Loss: 2.10e+00 Accuracy: 19.91%
# 2 / 50
# 	Train | Loss: 2.07e+00 Accuracy: 21.64%
# 	Train | Loss: 2.01e+00 Accuracy: 24.35%
# 3 / 50
# 	Train | Loss: 2.04e+00 Accuracy: 23.83%
# 	Train | Loss: 1.98e+00 Accuracy: 25.35%
# 4 / 50
# 	Train | Loss: 1.99e+00 Accuracy: 25.80%
# 	Train | Loss: 1.92e+00 Accuracy: 28.85%
# 5 / 50
# 	Train | Loss: 1.98e+00 Accuracy: 27.04%
# 	Train | Loss: 1.94e+00 Accuracy: 29.21%
# 6 / 50
# 	Train | Loss: 1.97e+00 Accuracy: 27.16%
# 	Train | Loss: 1.93e+00 Accuracy: 28.25%
# 7 / 50
# 	Train | Loss: 1.96e+00 Accuracy: 27.42%
# 	Train | Loss: 1.91e+00 Accuracy: 29.72%
# 8 / 50
# 	Train | Loss: 1.96e+00 Accuracy: 27.76%
# 	Train | Loss: 1.91e+00 Accuracy: 29.57%
# 9 / 50
# 	Train | Loss: 1.96e+00 Accuracy: 27.84%
# 	Train | Loss: 1.91e+00 Accuracy: 29.34%
# 10 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.22%
# 	Train | Loss: 1.90e+00 Accuracy: 30.87%
# 11 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.64%
# 	Train | Loss: 1.89e+00 Accuracy: 31.04%
# 12 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.55%
# 	Train | Loss: 1.90e+00 Accuracy: 30.87%
# 13 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.27%
# 	Train | Loss: 1.89e+00 Accuracy: 30.44%
# 14 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.89%
# 	Train | Loss: 1.89e+00 Accuracy: 31.24%
# 15 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.61%
# 	Train | Loss: 1.90e+00 Accuracy: 30.54%
# 16 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.77%
# 	Train | Loss: 1.90e+00 Accuracy: 30.91%
# 17 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.10%
# 	Train | Loss: 1.89e+00 Accuracy: 30.80%
# 18 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.86%
# 	Train | Loss: 1.89e+00 Accuracy: 30.88%
# 19 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.71%
# 	Train | Loss: 1.90e+00 Accuracy: 29.92%
# 20 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.07%
# 	Train | Loss: 1.89e+00 Accuracy: 31.67%
# 21 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 29.12%
# 	Train | Loss: 1.90e+00 Accuracy: 30.91%
# 22 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.03%
# 	Train | Loss: 1.89e+00 Accuracy: 30.86%
# 23 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 29.06%
# 	Train | Loss: 1.89e+00 Accuracy: 30.37%
# 24 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.85%
# 	Train | Loss: 1.89e+00 Accuracy: 32.14%
# 25 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 29.13%
# 	Train | Loss: 1.90e+00 Accuracy: 31.19%
# 26 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 29.09%
# 	Train | Loss: 1.89e+00 Accuracy: 31.81%
# 27 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.60%
# 	Train | Loss: 1.91e+00 Accuracy: 29.95%
# 28 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.06%
# 	Train | Loss: 1.88e+00 Accuracy: 31.10%
# 29 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.95%
# 	Train | Loss: 1.90e+00 Accuracy: 29.90%
# 30 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.96%
# 	Train | Loss: 1.89e+00 Accuracy: 31.02%
# 31 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.93%
# 	Train | Loss: 1.89e+00 Accuracy: 30.80%
# 32 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.96%
# 	Train | Loss: 1.89e+00 Accuracy: 30.55%
# 33 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.74%
# 	Train | Loss: 1.89e+00 Accuracy: 30.29%
# 34 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.95%
# 	Train | Loss: 1.89e+00 Accuracy: 31.29%
# 35 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.73%
# 	Train | Loss: 1.89e+00 Accuracy: 31.65%
# 36 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.01%
# 	Train | Loss: 1.89e+00 Accuracy: 30.68%
# 37 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 28.91%
# 	Train | Loss: 1.90e+00 Accuracy: 30.41%
# 38 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.05%
# 	Train | Loss: 1.88e+00 Accuracy: 31.68%
# 39 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 29.19%
# 	Train | Loss: 1.89e+00 Accuracy: 31.06%
# 40 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.73%
# 	Train | Loss: 1.90e+00 Accuracy: 30.82%
# 41 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.97%
# 	Train | Loss: 1.89e+00 Accuracy: 31.16%
# 42 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 29.09%
# 	Train | Loss: 1.88e+00 Accuracy: 31.85%
# 43 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 28.87%
# 	Train | Loss: 1.89e+00 Accuracy: 31.39%
# 44 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.09%
# 	Train | Loss: 1.89e+00 Accuracy: 30.91%
# 45 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.94%
# 	Train | Loss: 1.89e+00 Accuracy: 31.13%
# 46 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.81%
# 	Train | Loss: 1.89e+00 Accuracy: 31.16%
# 47 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.24%
# 	Train | Loss: 1.88e+00 Accuracy: 31.11%
# 48 / 50
# 	Train | Loss: 1.94e+00 Accuracy: 28.82%
# 	Train | Loss: 1.90e+00 Accuracy: 30.98%
# 49 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 28.99%
# 	Train | Loss: 1.90e+00 Accuracy: 30.60%
# 50 / 50
# 	Train | Loss: 1.95e+00 Accuracy: 29.13%
# 	Train | Loss: 1.89e+00 Accuracy: 31.32%
